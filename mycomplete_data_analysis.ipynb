# %% [markdown]
# ### **NAME**: AMBREEN ABDUL RAHEEM
# ### **SUBJECT**: EXPLORATORY DATA ANALYSIS AND DATA VISUALIZAATION
# ### **DATA NAME**: PROVIDE INSIGHTS TO THE MARKETING TEAM IN FOOD & BEVERAGE INDUSTRY
# ### **CONTACT**: ambreen.a.raheem@outlook.com
# ### **GitHub**: https://github.com/ambreenraheem

# %% [markdown]
# #### **ABOUT DATA**
# **CodeX** is a **German** beverage company that is aiming to make its mark in the Indian market. A few months ago, they launched their energy drink in 10 cities in **India**.
#
# Their Marketing team is responsible for increasing brand awareness, market share, and product development. They conducted a survey in those 10 cities and received results from 10k respondents.\
#  **Peter Pandey**, a marketing data analyst is tasked to convert these survey results to meaningful insights which the team can use to drive actions.

# %% [markdown]
# #### First we need to import some very important libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\Ambreen Abdulraheem\AppData\Local\Temp\ipykernel_3112\687462750.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# #### **DATA TRANSFORMATION**
# 1. Establishing suitable dimention tables and primary keys to like the csv files effictively.
# 2. Constructing aggregstion tables using append and groupby functions as needed to formate the data appropriately for answering the querries.\
#
# Let's upload our .csv files of databases in python with the help of pandas.\
# first df1 is (fact_survey_responses)\
# second df2 is (dim_repondent)\
# third df3 is (dim_cities)

# %%
df1=pd.read_csv(r"c:\Users\Ambreen Abdulraheem\Downloads\C6 Input Files\Dataset\fact_survey_responses.csv")
df1.head(5)
# Out:
#    Response_ID  Respondent_ID  Consume_frequency  \
# 0       103001         120031   2-3 times a week
# 1       103002         120032  2-3 times a month
# 2       103003         120033             Rarely
# 3       103004         120034   2-3 times a week
# 4       103005         120035              Daily
#
#                       Consume_time              Consume_reason Heard_before  \
# 0  To stay awake during work/study  Increased energy and focus          Yes
# 1               Throughout the day        To boost performance           No
# 2                  Before exercise  Increased energy and focus           No
# 3  To stay awake during work/study        To boost performance           No
# 4  To stay awake during work/study  Increased energy and focus          Yes
#
#   Brand_perception General_perception Tried_before  Taste_experience  ...  \
# 0          Neutral           Not sure           No                 5  ...
# ...

# %%
df2=pd.read_csv(r"c:\Users\Ambreen Abdulraheem\Downloads\C6 Input Files\Dataset\dim_repondents.csv")
df2.head(12)
# Out:
#     Respondent_ID            Name    Age  Gender City_ID
# 0          120031  Aniruddh Issac  15-18  Female   CT117
# 1          120032     Trisha Rout  19-30    Male   CT118
# 2          120033    Yuvraj  Virk  15-18    Male   CT116
# 3          120034    Pranay Chand  31-45  Female   CT113
# 4          120035  Mohanlal Joshi  19-30  Female   CT120
# 5          120036   Zeeshan Ratta  19-30  Female   CT118
# 6          120037      Oorja Anne  19-30    Male   CT112
# 7          120038     Rhea Khanna  19-30    Male   CT116
# 8          120039      Zara Joshi  46-65    Male   CT116
# 9          120040     Sana Dhawan  19-30  Female   CT116
# 10         120041   Misha Warrior  19-30  Female   CT113
# 11         120042   Kiara Chander  19-30  Female   CT112

# %%
df3=pd.read_csv(r"c:\Users\Ambreen Abdulraheem\Downloads\C6 Input Files\Dataset\dim_cities.csv")
df3
# Out:
#   City_ID       City    Tier
# 0   CT111      Delhi  Tier 1
# 1   CT112     Mumbai  Tier 1
# 2   CT113  Bangalore  Tier 1
# 3   CT114    Chennai  Tier 1
# 4   CT115    Kolkata  Tier 2
# 5   CT116  Hyderabad  Tier 1
# 6   CT117  Ahmedabad  Tier 2
# 7   CT118       Pune  Tier 2
# 8   CT119     Jaipur  Tier 2
# 9   CT120    Lucknow  Tier 2

# %% [markdown]
# #### Now We need to save all files in both csv and MS.Excell.

# %%
df1.to_excel("fact_survey_responses.xlsx")
df1.to_csv("fact_survey_responses.csv")

# %%
df2.to_excel("dim_repondents.xlsx")
df2.to_csv("dim_repondents.csv")

# %%
df3.to_excel("dim_cities.xlsx")
df3.to_csv("dim_cities.csv")

# %% [markdown]
# #### Let's do some initial analysis with pandas.
# #### Then we will continue our **Task**.

# %% [markdown]
# All the basic information of the dataset.

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 23 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Response_ID                     10000 non-null  int64
#  1   Respondent_ID                   10000 non-null  int64
#  2   Consume_frequency               10000 non-null  object
#  3   Consume_time                    10000 non-null  object
#  4   Consume_reason                  10000 non-null  object
#  5   Heard_before                    10000 non-null  object
#  6   Brand_perception                10000 non-null  object
#  7   General_perception              10000 non-null  object
#  8   Tried_before                    10000 non-null  object
#  9   Taste_experience                10000 non-null  int64
#  10  Reasons_preventing_trying       10000 non-null  object
#  11  Current_brands                  10000 non-null  object
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Respondent_ID  10000 non-null  int64
#  1   Name           10000 non-null  object
#  2   Age            10000 non-null  object
#  3   Gender         10000 non-null  object
#  4   City_ID        10000 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 390.8+ KB

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   City_ID  10 non-null     object
#  1   City     10 non-null     object
#  2   Tier     10 non-null     object
# dtypes: object(3)
# memory usage: 372.0+ bytes

# %% [markdown]
# Let's check it out if there are null values in both datasets.
# (We have large numbers of null values in both datasets but there is no need of droping these columns,because we need NOTA values form it.)

# %%
df1.isnull().sum()
# Out:
# Response_ID                       0
# Respondent_ID                     0
# Consume_frequency                 0
# Consume_time                      0
# Consume_reason                    0
# Heard_before                      0
# Brand_perception                  0
# General_perception                0
# Tried_before                      0
# Taste_experience                  0
# Reasons_preventing_trying         0
# Current_brands                    0
# Reasons_for_choosing_brands       0
# Improvements_desired              0
# Ingredients_expected              0
# Health_concerns                   0
# Interest_in_natural_or_organic    0
# Marketing_channels                0
# Packaging_preference              0
# Limited_edition_packaging         0
# Price_range                       0
# Purchase_location                 0
# Typical_consumption_situations    0
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# Respondent_ID    0
# Name             0
# Age              0
# Gender           0
# City_ID          0
# dtype: int64

# %%
df3.isnull().sum()
# Out:
# City_ID    0
# City       0
# Tier       0
# dtype: int64

# %% [markdown]
# **It's good to see that there are no null values in any of these datasets.**

# %% [markdown]
# ## From here we will start analysis with the help of MySQL.
# #### What is MySQL?
# #### Structured Query Language (SQL) is a standard computer language for retional data base management and data manipulation.
# #### 1. Demographic Insights:
# Questions that we need to find out from our total data.\
# a. Who prefers enegy drink more? (Male or Female - non_binary)\
# b. Which age group prefers energy drinks more?\
# c. Which type of marketing reaches the most youth (15-30)?\
# \
# This CSV file was generated by MySQL.\
# "I joined two tables using MySQL and selected five important columns to answer all questions from 'Demographic Insight'."

# %%
demographic_insights1=pd.read_csv(r"Demographic_sql1.csv")
demographic_insights1
demographic_insights1.to_excel("Demographic_sql1.xlsx")
demographic_insights1.to_csv("Demographic_sql1.csv")
print(demographic_insights1.drop(demographic_insights1.columns[[0, 1]], axis=1))
print(type(demographic_insights1))
# Out:
#       Respondent_ID      Gender    Age Current_brands  Marketing_channels  \
# 0            120031      Female  15-18      Blue Bull      TV commercials
# 1            120032        Male  19-30          Bepsi         Print media
# 2            120033        Male  15-18          Bepsi          Online ads
# 3            120034      Female  31-45          Bepsi          Online ads
# 4            120035      Female  19-30          Sky 9          Online ads
# ...             ...         ...    ...            ...                 ...
# 9995         130020      Female  19-30          Bepsi         Print media
# 9996         130021        Male  31-45          Bepsi      TV commercials
# 9997         130024  Non-binary  19-30      Blue Bull          Online ads
# 9998         130027        Male  15-18       Gangster      TV commercials
# 9999         130028        Male  31-45      Blue Bull  Outdoor billboards
#
#       Consume_frequency
# 0      2-3 times a week
# 1     2-3 times a month
# ...

# %%
# Q. a: Who prefers enegy drink more? (Male or Female - non_binary)
demo_insights=demographic_insights1.value_counts(['Gender', 'Current_brands'])
demo_insights
# Out:
# Gender      Current_brands
# Male        Cola-Coka         1604
#             Bepsi             1208
#             Gangster          1154
# Female      Cola-Coka          809
#             Bepsi              783
#             Gangster           613
# Male        Blue Bull          603
#             CodeX              590
#             Sky 9              588
# Female      Blue Bull          403
#             CodeX              352
#             Sky 9              332
# Male        Others             291
# Female      Others             163
# Non-binary  Cola-Coka          125
#             Bepsi              121
#             Gangster            87
#             Sky 9               59
#             Blue Bull           52
#             CodeX               38
#             Others              25
# Name: count, dtype: int64

# %%
demo_insights1=demographic_insights1.value_counts(['Gender'])
demo_insights1
# Out:
# Gender
# Male          6038
# Female        3455
# Non-binary     507
# Name: count, dtype: int64

# %% [markdown]
# "The bar plot provides a comprehensive visualization of the data related to brand preferences by gender & Brands."\
# "What we found in question (a) is that **males** prefer energy drinks more."

# %%
# Bar plot
demo_insights.plot(kind='bar', stacked=True, figsize=(12, 6))
plt.title('Brand Preferences by Gender')
plt.xlabel('Gender & Brands')
plt.ylabel('Counts')
plt.xticks(rotation=45)
plt.legend(title='Gender & Brands')
plt.tight_layout()
plt.show()

# %%
# Bar plot
demo_insights1.plot(kind='bar', stacked=True, figsize=(12, 6))
plt.title('Energy Drink Preferences by Gender')
plt.xlabel('Gender')
plt.ylabel('Counts')
plt.xticks(rotation=45)
plt.legend(title='Gender')
plt.tight_layout()
plt.show()

# %%
# Q. b: Which age group prefers energy drinks more?
demo_age_insights=demographic_insights1.value_counts(['Age', 'Consume_frequency'])
demo_age_insights
# Out:
# Age    Consume_frequency
# 19-30  2-3 times a week     1917
#        Rarely               1088
#        2-3 times a month     891
#        Once a week           888
# 31-45  2-3 times a week      809
# 19-30  Daily                 736
# 15-18  2-3 times a week      539
# 31-45  Rarely                460
#        2-3 times a month     398
#        Once a week           361
#        Daily                 348
# 15-18  Rarely                277
#        Once a week           244
#        2-3 times a month     232
#        Daily                 196
# 46-65  2-3 times a week      155
#        Once a week            86
#        Rarely                 77
# 65+    2-3 times a week       71
# 46-65  2-3 times a month      66
#        Daily                  42
# 65+    Rarely                 39
#        Once a week            30
#        2-3 times a month      26
#        Daily                  24
# Name: count, dtype: int64

# %%
demo_age_insights1=demographic_insights1.value_counts(['Age'])
demo_age_insights1
# Out:
# Age
# 19-30    5520
# 31-45    2376
# 15-18    1488
# 46-65     426
# 65+       190
# Name: count, dtype: int64

# %% [markdown]
# "The bar plot provides a comprehensive visualization of the data related to brand preferences by age group and consumption frequency."\
# "What we found in question (b) is that the **age group of 19-30** prefers energy drinks more."

# %%
# Bar plot
demo_age_insights.plot(kind='bar', stacked=True, figsize=(12, 6))
plt.title('Energy Drink Preferences by Age Group & Consumption frequency')
plt.xlabel('Age & Consume_frequency')
plt.ylabel('Counts')
plt.xticks(rotation=45)
plt.legend(title='Age & Consume_frequency')
plt.tight_layout()
plt.show()

# %%
demo_age_insights1.plot(kind='bar', stacked=True, figsize=(12, 6))
plt.title('Energy Drink Preferences by Age Group')
plt.xlabel('Age')
plt.ylabel('Counts')
plt.xticks(rotation=45)
plt.legend(title='Age')
plt.tight_layout()
plt.show()

# %%
#Q. c: Which type of marketing reaches the most youth (15-30)?
demo_market_insights=demographic_insights1.value_counts(['Age', 'Marketing_channels'])
demo_market_insights
# Out:
# Age    Marketing_channels
# 19-30  Online ads            2666
#        TV commercials        1290
# 31-45  TV commercials         737
# 15-18  Online ads             707
# 19-30  Other                  608
#        Outdoor billboards     585
# 15-18  TV commercials         495
# 31-45  Online ads             490
#        Outdoor billboards     431
#        Other                  408
# 19-30  Print media            371
# 31-45  Print media            310
# 15-18  Outdoor billboards     117
# 46-65  TV commercials         117
#        Online ads             109
# 15-18  Other                   94
# 46-65  Other                   78
# 15-18  Print media             75
# 46-65  Outdoor billboards      65
#        Print media             57
# 65+    TV commercials          49
#        Online ads              48
#        Other                   37
#        Outdoor billboards      28
#        Print media             28
# Name: count, dtype: int64

# %%
demo_market_insights1=demographic_insights1.value_counts(['Marketing_channels'])
demo_market_insights1
# Out:
# Marketing_channels
# Online ads            4020
# TV commercials        2688
# Outdoor billboards    1226
# Other                 1225
# Print media            841
# Name: count, dtype: int64

# %% [markdown]
# "This bar plot provides an in-depth representation of marketing channels across different age groups."\
# "What we found in question (c) is that the **age group of 15-30** is the most targeted by marketing aimed at youth."

# %%
demo_market_insights.plot(kind='bar', stacked=True, figsize=(12, 6))
plt.title('Age Group across different "Marketing Channels"')
plt.xlabel('Age & Marketing Channels')
plt.ylabel('Counts')
plt.xticks(rotation=45)
plt.legend(title='Age & Marketing Channels')
plt.tight_layout()
plt.show()

# %%
demo_market_insights1.plot(kind='bar', stacked=True, figsize=(12, 6))
plt.title('Age Group across different "Marketing Channels"')
plt.xlabel('Marketing Channels')
plt.ylabel('Counts')
plt.xticks(rotation=45)
plt.legend(title='Marketing Channels')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 2. Cunsumer Preferences:
# Questions that we need to find out from our total data.\
# \
# Here we need first df1, which is (fact_survey_responses)\
# a. What are the preferred ingredints of energy drinks among respondents?\
# b. What packaging preferences do repondent have for energy drink?

# %%
# a. What are the preferred ingredints of energy drinks among respondents?
df1.Ingredients_expected.value_counts()
# Out:
# Ingredients_expected
# Caffeine    3896
# Vitamins    2534
# Sugar       2017
# Guarana     1553
# Name: count, dtype: int64

# %% [markdown]
# "What we found in question (a) is that the respondents preferred **caffeine** ingredients in energy drinks."

# %%
ingredient_counts = df1['Ingredients_expected'].value_counts().reset_index()
ingredient_counts.columns = ['Ingredients', 'Count']

# Plotting
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.barplot(x='Ingredients', y='Count', data=ingredient_counts, palette='Blues_d')
plt.title('Ingredients Expected Count')
plt.xlabel('Ingredients')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.grid(axis='y')

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Ambreen Abdulraheem\AppData\Local\Temp\ipykernel_3112\1816892554.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Ingredients', y='Count', data=ingredient_counts, palette='Blues_d')

# %%
# b. What packaging preferences do respondent have for energy drink?
df1.Packaging_preference.value_counts()
# Out:
# Packaging_preference
# Compact and portable cans    3984
# Innovative bottle design     3047
# Collectible packaging        1501
# Eco-friendly design           983
# Other                         485
# Name: count, dtype: int64

# %% [markdown]
# "What we found in question (a) is that the respondents preferred **Compact and portable cans** for energy drinks."

# %%
Packaging_counts = df1['Packaging_preference'].value_counts().reset_index()
Packaging_counts.columns = ['Packaging', 'Count']

# Plotting
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.barplot(x='Packaging', y='Count', data=Packaging_counts, palette='Reds_d')
plt.title('Packaging Expected Count')
plt.xlabel('Packaging')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.grid(axis='y')

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Ambreen Abdulraheem\AppData\Local\Temp\ipykernel_3112\900174007.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Packaging', y='Count', data=Packaging_counts, palette='Reds_d')

# %% [markdown]
# #### 3. Competition Analysis:
# a. Who current market leaders?\
# b. What are the Primary reasons consumers prefer those brande over our?

# %%
# a. Who current market leaders?
df1.Current_brands.value_counts()
# Out:
# Current_brands
# Cola-Coka    2538
# Bepsi        2112
# Gangster     1854
# Blue Bull    1058
# CodeX         980
# Sky 9         979
# Others        479
# Name: count, dtype: int64

# %% [markdown]
# **Cola-Cola, Bepsi, Gangster, and Blue Bull** are established brands that have been in the market for many years in **India**, which is why they appear at the top of the list of current brands.\
#  However, a few months ago, a **German company** launched their energy drink, **CodeX**, in 10 cities across **India**.

# %% [markdown]
# This CSV file was generated by MySQL.\
# "I joined two tables using MySQL and selected five important columns to answer the questions from 'Competition Analysis'."

# %%
current_Brand_counts = df1['Current_brands'].value_counts().reset_index()
current_Brand_counts.columns = ['Brand', 'Count']

# Plotting
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.barplot(x='Brand', y='Count', data=current_Brand_counts, palette='Greens_d')
plt.title('Current Brand Market Leader')
plt.xlabel('Brand')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.grid(axis='y')

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Ambreen Abdulraheem\AppData\Local\Temp\ipykernel_3112\2873371250.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Brand', y='Count', data=current_Brand_counts, palette='Greens_d')

# %%
Competition=pd.read_csv(r"competition_analysis1.csv")
Competition
# Competition.to_excel("competition_analysis1.xlsx")
# Competition.to_csv("competition_analysis1.csv")
print(Competition.drop(Competition.columns[[0, 1]], axis=1))
# Out:
#       Respondent_ID  Gender    Age Reasons_for_choosing_brands Current_brands
# 0            120031  Female  15-18                Availability      Blue Bull
# 1            120032    Male  19-30                Availability          Bepsi
# 2            120033    Male  15-18                Availability          Bepsi
# 3            120034  Female  31-45                       Other          Bepsi
# 4            120035  Female  19-30                       Other          Sky 9
# ...             ...     ...    ...                         ...            ...
# 9995         130026    Male  31-45            Brand reputation      Cola-Coka
# 9996         130027    Male  15-18               Effectiveness       Gangster
# 9997         130028    Male  31-45                Availability      Blue Bull
# 9998         130029    Male  19-30     Taste/flavor preference      Blue Bull
# 9999         130030    Male  15-18            Brand reputation          Bepsi
#
# [10000 rows x 5 columns]

# %%
# b. What are the Primary reasons consumers prefer those brande over our?
Competition.value_counts(['Current_brands', 'Reasons_for_choosing_brands'])
# Out:
# Current_brands  Reasons_for_choosing_brands
# Cola-Coka       Brand reputation               616
# Bepsi           Brand reputation               577
# Cola-Coka       Taste/flavor preference        531
# Gangster        Brand reputation               511
# Cola-Coka       Availability                   510
#                 Other                          448
#                 Effectiveness                  433
# Bepsi           Taste/flavor preference        423
#                 Availability                   418
# Gangster        Taste/flavor preference        357
# Bepsi           Other                          355
#                 Effectiveness                  339
# Gangster        Availability                   339
#                 Effectiveness                  338
#                 Other                          309
# Blue Bull       Brand reputation               289
# Sky 9           Brand reputation               260
# CodeX           Brand reputation               259
# ...

# %% [markdown]
# Here **Cola_Coka** is the No.1 Brand.\
# Primary Reasons Consumers Prefer Those Brands Over Ours:
# 1. Brand reputation
# 2. Taste/flavor preference
# 3. Availability

# %%
df1.Reasons_for_choosing_brands.value_counts()
# Out:
# Reasons_for_choosing_brands
# Brand reputation           2652
# Taste/flavor preference    2011
# Availability               1910
# Effectiveness              1748
# Other                      1679
# Name: count, dtype: int64

# %%
choosing_Brand_counts = df1['Reasons_for_choosing_brands'].value_counts().reset_index()
choosing_Brand_counts.columns = ['Reasons', 'Count']

# Plotting
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.barplot(x='Reasons', y='Count', data=choosing_Brand_counts, palette='Purples_d')
plt.title('The Primary reasons consumers prefer other brande over our "CodeX"')
plt.xlabel('Reasons')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.grid(axis='y')

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Ambreen Abdulraheem\AppData\Local\Temp\ipykernel_3112\2458675833.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Reasons', y='Count', data=choosing_Brand_counts, palette='Purples_d')

# %% [markdown]
# #### 4. Marketing Channals and Brand Awarness:
# a. Which marketing channel can be used to reach more customers?\
# b. How effective are different marketing strategies and channels in reaching our customers?

# %%
df1.Marketing_channels.value_counts()
# Out:
# Marketing_channels
# Online ads            4020
# TV commercials        2688
# Outdoor billboards    1226
# Other                 1225
# Print media            841
# Name: count, dtype: int64

# %% [markdown]
# a. Based on the data provided, **Online Ads** can be used to reach the most customers, with a total of **4020**.
#
# This channel likely offers the widest reach and engagement potential, especially in today’s digital landscape.

# %% [markdown]
# b. How effective are different marketing strategies and channels in reaching our customers?
# 1. **Online Ads**\
# Effectiveness: Highly effective due to the ability to target specific demographics and track engagement metrics.\
# Reach: 4020 customers.
# Considerations: Utilize social media platforms, search engines, and display ads to maximize reach.
# 2. **TV Commercials**\
# Effectiveness: Effective for broad reach and brand awareness, especially among older demographics.\
# Reach: 2688 customers.
# Considerations: High production costs but can create a strong emotional connection with viewers.
# 3. **Outdoor Billboards**\
# Effectiveness: Good for local brand visibility and reaching commuters.\
# Reach: 1226 customers.
# Considerations: Limited targeting; best used in high-traffic areas.
# 4. **Print Media**\
# Effectiveness: Less effective in the digital age but can still reach specific demographics.\
# Reach: 841 customers.
# Considerations: Best for niche markets or local advertising.
# 5. **Other Channels**\
# Effectiveness: Varies widely depending on the specific channel used.\
# Reach: 1225 customers.
# Considerations: Can include events, sponsorships, or guerrilla marketing, depending on the target audience.
# Conclusion
# To effectively reach customers, a multi-channel approach is recommended. Combining high-reach channels like Online Ads and TV Commercials with more targeted strategies can enhance overall effectiveness. Regularly analyzing customer engagement and feedback will help refine these strategies over time.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
Marketing_channels_counts = df1['Marketing_channels'].value_counts().reset_index()
Marketing_channels_counts.columns = ['Marketing_channels', 'Count']

# Plotting
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.barplot(x='Marketing_channels', y='Count', data = Marketing_channels_counts, palette='Oranges_d')
plt.title('Online Ads for Marketing can be used to reach more customers for our "CodeX"')
plt.xlabel('Marketing_channels')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.grid(axis='y')

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Ambreen Abdulraheem\AppData\Local\Temp\ipykernel_3112\1721357826.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Marketing_channels', y='Count', data = Marketing_channels_counts, palette='Oranges_d')

# %% [markdown]
# #### 5. Brand Penetration:
# a. What do people think about our brand? (Overall Rating)\
# b. Which cities do we need to focus more on?

# %%
brand_penetration=pd.read_csv(r"Brand_penetration2.csv")
print(brand_penetration)
brand_penetration.to_excel("Brand_penetration2.xlsx")
brand_penetration.to_csv("Brand_penetration2.csv")
# Out:
#       Unnamed: 0.1  Unnamed: 0  Respondent_ID    Age  Gender City_ID  \
# 0                0           0         120031  15-18  Female   CT117
# 1                1           1         120032  19-30    Male   CT118
# 2                2           2         120033  15-18    Male   CT116
# 3                3           3         120034  31-45  Female   CT113
# 4                4           4         120035  19-30  Female   CT120
# ...            ...         ...            ...    ...     ...     ...
# 9995          9995        9995         130026  31-45    Male   CT112
# 9996          9996        9996         130027  15-18    Male   CT113
# 9997          9997        9997         130028  31-45    Male   CT114
# 9998          9998        9998         130029  19-30    Male   CT113
# 9999          9999        9999         130030  15-18    Male   CT112
#
#            City    Tier Current_brands
# 0     Ahmedabad  Tier 2      Blue Bull
# 1          Pune  Tier 2          Bepsi
# ...

# %%
brand_penetration.value_counts(['Tier', 'Current_brands', 'City'])
# Out:
# Tier    Current_brands  City
# Tier 1  Cola-Coka       Bangalore    667
#         Bepsi           Bangalore    594
#         Gangster        Bangalore    552
#         Cola-Coka       Hyderabad    474
#         Bepsi           Hyderabad    419
#                                     ...
# Tier 2  Sky 9           Lucknow       22
#         Blue Bull       Lucknow       20
#         Others          Jaipur        15
#         CodeX           Lucknow        5
#         Others          Lucknow        5
# Name: count, Length: 70, dtype: int64

# %% [markdown]
# #### "We have obtained both answers using .value_counts() from the Brand_penetration.csv file."
# a. What do people think about our brand? (Overall Rating)\
# b. Which cities do we need to focus more on?

# %% [markdown]
# **Current Performance:**
# CodeX (Lucknow): 5\
# Other Tier 2 Brands in Lucknow:\
# Sky 9: 22\
# Blue Bull: 20\
# Others: 5\
# **Observations:**\
# **Low Sales:**\
#  CodeX has very low sales compared to other Tier 2 brands in Lucknow (only 5).\
# **Market Presence:** \
# The sales numbers indicate that CodeX is not performing well and is on par with the "Others" category, which suggests a lack of brand recognition or demand.
#
#
# **Low Sales Performance:**
#
# With only 5 sales in Lucknow, CodeX is significantly trailing behind competitors like Sky 9 (22) and Blue Bull (20). This low performance may lead consumers to perceive CodeX as less popular or less desirable.

# %%
# Sample data creation (you should replace this with your actual DataFrame)
data = {
    'Tier': ['Tier 1', 'Tier 1', 'Tier 1', 'Tier 1', 'Tier 1', 'Tier 2', 'Tier 2', 'Tier 2', 'Tier 2', 'Tier 2'],
    'Current_brands': ['Cola-Coka', 'Bepsi', 'Gangster', 'Cola-Coka', 'Bepsi', 'Sky 9', 'Blue Bull', 'Others', 'CodeX', 'Others'],
    'City': ['Bangalore', 'Bangalore', 'Bangalore', 'Hyderabad', 'Hyderabad', 'Lucknow', 'Lucknow', 'Jaipur', 'Lucknow', 'Lucknow'],
    'Count': [667, 594, 552, 474, 419, 22, 20, 15, 5, 5]
}

df = pd.DataFrame(data)

# Plotting
plt.figure(figsize=(12, 6))
sns.barplot(data=df, x='Current_brands', y='Count', hue='City', palette='Set2')
plt.title('Brand Penetration by City')
plt.xlabel('Current Brands')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='City')
plt.grid(axis='y')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 6. Purchase Behaviour:
# a. Where do respondents prefer to purchase energy drinks?\
# b. What are the typical consumption situations for energy drink among respondents?\
# c. What factors, influence respondent purchase decisions, such as price range and limited edition packaging?

# %%
# a. Where do respondents prefer to purchase energy drinks?
df1.Purchase_location.value_counts()
# Out:
# Purchase_location
# Supermarkets                4494
# Online retailers            2550
# Gyms and fitness centers    1464
# Local stores                 813
# Other                        679
# Name: count, dtype: int64

# %% [markdown]
# Based on the data, **Supermarkets** can be used to reach the most customers, with a total of 4494.\
#  This suggests that supermarkets are the most popular purchase location among consumers.

# %%
Purchase_location_counts = df1['Purchase_location'].value_counts().reset_index()
Purchase_location_counts.columns = ['Purchase_location', 'Count']

# Plotting
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.barplot(x='Purchase_location', y='Count', data=Purchase_location_counts, palette='Purples_d')
plt.title('respondents prefer to purchase energy drinks from Supermarkets')
plt.xlabel('Purchase_location')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.grid(axis='y')

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Ambreen Abdulraheem\AppData\Local\Temp\ipykernel_7880\900961368.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Purchase_location', y='Count', data=Purchase_location_counts, palette='Purples_d')

# %%
# b. typical consumption
typical_consumption=pd.read_csv(r"c:\Users\Ambreen Abdulraheem\Desktop\mysql work\Typical_consumption_situations1.csv")
typical_consumption
# typical_consumption.to_excel("Typical_consumption_situation1.xlsx")
# typical_consumption.to_csv("Typical_consumption_situation1.csv")
# Out:
#       Respondent_ID  Gender    Age Typical_consumption_situations  \
# 0            120031  Female  15-18          Studying/working late
# 1            120032    Male  19-30                Sports/exercise
# 2            120033    Male  15-18          Studying/working late
# 3            120034  Female  31-45                Sports/exercise
# 4            120035  Female  19-30          Studying/working late
# ...             ...     ...    ...                            ...
# 9995         130026    Male  31-45          Studying/working late
# 9996         130027    Male  15-18         Social outings/parties
# 9997         130028    Male  31-45                Sports/exercise
# 9998         130029    Male  19-30          Studying/working late
# 9999         130030    Male  15-18                Sports/exercise
#
#      Current_brands
# 0         Blue Bull
# 1             Bepsi
# 2             Bepsi
# 3             Bepsi
# 4             Sky 9
# ...             ...
# 9995      Cola-Coka
# ...

# %%
# b. What are the typical consumption situations for energy drink among respondents?
df1.Typical_consumption_situations.value_counts()
# Out:
# Typical_consumption_situations
# Sports/exercise           4494
# Studying/working late     3231
# Social outings/parties    1487
# Other                      491
# Driving/commuting          297
# Name: count, dtype: int64

# %%
typical_consumption_counts = df1['Typical_consumption_situations'].value_counts().reset_index()
typical_consumption_counts.columns = ['Typical_consumption_situations', 'Count']

# Plotting
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.barplot(x='Typical_consumption_situations', y='Count', data=typical_consumption_counts, palette='Blues_d')
plt.title('The Typical consumption situations for energy drink among respondents')
plt.xlabel('Typical_consumption_situations')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.grid(axis='y')

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Ambreen Abdulraheem\AppData\Local\Temp\ipykernel_7880\2446836840.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Typical_consumption_situations', y='Count', data=typical_consumption_counts, palette='Blues_d')

# %%
typical_consumption.value_counts(['Gender', 'Current_brands','Typical_consumption_situations'])
# Out:
# Gender      Current_brands  Typical_consumption_situations
# Male        Cola-Coka       Sports/exercise                   708
#                             Studying/working late             544
#             Bepsi           Sports/exercise                   543
#             Gangster        Sports/exercise                   519
#             Bepsi           Studying/working late             380
#                                                              ...
# Non-binary  Sky 9           Other                               3
#             CodeX           Other                               3
#             Blue Bull       Other                               2
#             Sky 9           Driving/commuting                   1
#             CodeX           Driving/commuting                   1
# Name: count, Length: 102, dtype: int64

# %% [markdown]
# The primary consumption situations for energy drinks are during **"sports/exercise"** and **"studying/working late"**, with social outings and commuting also being notable contexts.

# %%
# data creation (replace this with your actual DataFrame) with dictionary
data = {
    'Gender': ['Male', 'Male', 'Male', 'Male', 'Male', 'Non-binary', 'Non-binary', 'Non-binary', 'Non-binary', 'Non-binary'],
    'Current_brands': [
        'Cola-Coka', 'Cola-Coka', 'Bepsi', 'Gangster', 'Bepsi',
        'Sky 9', 'CodeX', 'Blue Bull', 'Sky 9', 'CodeX'
    ],
    'Typical_consumption_situations': [
        'Sports/exercise', 'Studying/working late', 'Sports/exercise', 'Sports/exercise', 'Studying/working late',
        'Other', 'Other', 'Other', 'Driving/commuting', 'Driving/commuting'
    ],
    'Count': [708, 544, 543, 519, 380, 3, 3, 2, 1, 1]
}

df = pd.DataFrame(data)

# Plotting
plt.figure(figsize=(12, 6))
sns.barplot(data=df,x='Typical_consumption_situations', y='Count', hue='Current_brands', palette='Set1')
plt.title('Typical Consumption Situations by Current Brands and Gender')
plt.xlabel('Typical Consumption Situations')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Current Brands')
plt.grid(axis='y')

# Show the plot
plt.tight_layout()
plt.show()

# %%
# c. What factors, influence respondent purchase decisions, such as price range and limited edition packaging?
df1.value_counts(['Price_range', 'Limited_edition_packaging', 'Current_brands'])
# Out:
# Price_range  Limited_edition_packaging  Current_brands
# 50-99        No                         Cola-Coka         462
#              Yes                        Cola-Coka         450
#              No                         Bepsi             389
#              Yes                        Bepsi             354
# 100-150      No                         Cola-Coka         315
#                                                          ...
# Below 50     Not Sure                   Blue Bull          22
#                                         CodeX              21
#                                         Sky 9              18
#              No                         Others             14
#              Not Sure                   Others             13
# Name: count, Length: 84, dtype: int64

# %%
# data creation (replace this with your actual DataFrame) with dictionary
data = {
    'Gender': ['Male', 'Male', 'Male', 'Male', 'Male', 'Non-binary', 'Non-binary', 'Non-binary', 'Non-binary', 'Non-binary'],
    'Current_brands': [
        'Cola-Coka', 'Cola-Coka', 'Bepsi', 'Gangster', 'Bepsi',
        'Sky 9', 'CodeX', 'Blue Bull', 'Sky 9', 'CodeX'
    ],
    'Typical_consumption_situations': [
        'Sports/exercise', 'Studying/working late', 'Sports/exercise', 'Sports/exercise', 'Studying/working late',
        'Other', 'Other', 'Other', 'Driving/commuting', 'Driving/commuting'
    ],
    'Count': [708, 544, 543, 519, 380, 3, 3, 2, 1, 1]
}

df = pd.DataFrame(data)

# Plotting
plt.figure(figsize=(12, 6))
sns.barplot(data=df, x='Typical_consumption_situations', y='Count', hue='Current_brands', palette='Set1')
plt.title('Typical Consumption Situations by Current Brands and Gender')
plt.xlabel('Typical Consumption Situations')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Current Brands')
plt.grid(axis='y')

# Show the plot
plt.tight_layout()
plt.show()

# %%
df1.value_counts(['Price_range', 'Limited_edition_packaging'])
# Out:
# Price_range  Limited_edition_packaging
# 50-99        No                           1741
#              Yes                          1679
# 100-150      Yes                          1263
#              No                           1244
# 50-99        Not Sure                      868
# Above 150    No                            639
# 100-150      Not Sure                      635
# Above 150    Yes                           600
# Below 50     Yes                           404
#              No                            399
# Above 150    Not Sure                      322
# Below 50     Not Sure                      206
# Name: count, dtype: int64

# %%
# data creation (replace this with your actual DataFrame) with dictionary
data = {
    'Price_range': [
        '50-99', '50-99', '100-150', '100-150', 
        '50-99', 'Above 150', '100-150', 'Above 150', 
        'Below 50', 'Below 50', 'Above 150', 'Below 50'
    ],
    'Limited_edition_packaging': [
        'No', 'Yes', 'Yes', 'No', 
        'Not Sure', 'No', 'Not Sure', 'Yes', 
        'Yes', 'No', 'Not Sure', 'Not Sure'
    ],
    'Count': [
        1741, 1679, 1263, 1244, 
        868, 639, 635, 600, 
        404, 399, 322, 206
    ]
}

df = pd.DataFrame(data)

# Plotting
plt.figure(figsize=(12, 6))
sns.barplot(data=df, x='Price_range', y='Count', hue='Limited_edition_packaging', palette='Set2')
plt.title('Count by Price Range and Limited Edition Packaging')
plt.xlabel('Price Range')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Limited Edition Packaging')
plt.grid(axis='y')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Based on the provided data regarding price range, limited edition packaging, and current brands, several factors influence respondents' purchase decisions for energy drinks:
# **Price Range:**\
# 50-99:\
# This price range shows strong sales for both Cola-Coka (462 for no, 450 for yes) and Bepsi (389 for no, 354 for yes). The numbers indicate that this range is highly appealing to consumers, suggesting they are willing to purchase within this bracket regardless of packaging type.\
# 100-150:\
# While specific brand data isn't fully provided, the trend continues that this range might attract consumers looking for a balance between quality and price. Brands with limited edition offerings in this range could see increased interest.\
# Below 50:\
# The data shows lower sales figures overall, indicating that this price range may be less attractive. Brands like Blue Bull (22), CodeX (21), and Sky 9 (18) show limited interest, suggesting that consumers may perceive lower-priced options as lower quality.
#
# **Limited Edition Packaging:**\
# **Appeal of Limited Editions:**\
# The presence of limited edition packaging influences purchase decisions positively, especially for popular brands like Cola-Coka and Bepsi. For example, the numbers for Cola-Coka (450 for yes vs. 462 for no in the 50-99 range) indicate that limited editions are still a strong consideration, even if not the leading factor.
#
# **Consumer Uncertainty:**\
# **Not Sure Responses:**\
# The "Not Sure" responses **(e.g., Blue Bull, CodeX, Sky 9)** reflect uncertainty in consumer preferences. This suggests that some consumers may need more information or marketing efforts to clarify the benefits of both price and packaging.

# %% [markdown]
# #### 7. Product Development:
# a. Which area of business should we focus more on our product development (Branding-Taste/ Availability)?

# %%
# a. Which area of business should we focus more on our product development (Branding-Taste/ Availability)?
product_development=pd.read_csv(r"c:\Users\Ambreen Abdulraheem\Desktop\mysql work\Product_development.csv")
product_development
# Out:
#     City_ID       City Current_brands Reasons_for_choosing_brands  \
# 0     CT113  Bangalore          CodeX                       Other
# 1     CT112     Mumbai          CodeX     Taste/flavor preference
# 2     CT114    Chennai          CodeX            Brand reputation
# 3     CT115    Kolkata          CodeX                Availability
# 4     CT116  Hyderabad          CodeX     Taste/flavor preference
# ..      ...        ...            ...                         ...
# 975   CT116  Hyderabad          CodeX                       Other
# 976   CT120    Lucknow          CodeX                       Other
# 977   CT116  Hyderabad          CodeX            Brand reputation
# 978   CT114    Chennai          CodeX                       Other
# 979   CT113  Bangalore          CodeX            Brand reputation
#
#      Taste_experience
# 0                   5
# 1                   4
# 2                   3
# 3                   2
# 4                   2
# ..                ...
# ...

# %%
product_development.sort_values(['City','Current_brands','Reasons_for_choosing_brands','Taste_experience'])
# Out:
#     City_ID       City Current_brands Reasons_for_choosing_brands  \
# 268   CT117  Ahmedabad          CodeX                Availability
# 369   CT117  Ahmedabad          CodeX                Availability
# 822   CT117  Ahmedabad          CodeX                Availability
# 229   CT117  Ahmedabad          CodeX            Brand reputation
# 974   CT117  Ahmedabad          CodeX            Brand reputation
# ..      ...        ...            ...                         ...
# 552   CT118       Pune          CodeX     Taste/flavor preference
# 934   CT118       Pune          CodeX     Taste/flavor preference
# 19    CT118       Pune          CodeX     Taste/flavor preference
# 247   CT118       Pune          CodeX     Taste/flavor preference
# 306   CT118       Pune          CodeX     Taste/flavor preference
#
#      Taste_experience
# 268                 4
# 369                 4
# 822                 5
# 229                 2
# 974                 2
# ..                ...
# ...

# %%
pd.set_option('display.max.row',980)

# %%
product_development.value_counts()
# Out:
# City_ID  City       Current_brands  Reasons_for_choosing_brands  Taste_experience
# CT113    Bangalore  CodeX           Availability                 3                   24
#                                     Brand reputation             3                   22
#                                     Taste/flavor preference      3                   20
#                                     Effectiveness                3                   19
#                                                                  4                   18
#                                     Brand reputation             4                   16
#                                     Availability                 4                   16
#                                     Other                        3                   15
# CT112    Mumbai     CodeX           Brand reputation             5                   15
# CT113    Bangalore  CodeX           Other                        5                   14
# ...

# %%
product_development.value_counts().max()
# Out:
# 24

# %% [markdown]
# Based on the data provided, here are some insights to determine which area of business to focus on for product development:
#
# **Key Areas of Focus
# Branding:**
#
# **Importance:** \
# Brand reputation is frequently cited across multiple cities, especially in Mumbai and Pune. High ratings in brand reputation (up to 5) suggest that consumers value the brand image.
# **Current Status:** While brand reputation is strong in some areas, there are still opportunities for improvement, particularly in cities with lower ratings.
#
# **Taste/Flavor Preference:**
#
# **Importance:** Taste is a significant factor influencing consumer choice, especially in Mumbai and Bangalore. The scores for taste/flavor preference are generally positive, indicating that it is a crucial area for customer satisfaction.
# **Current Status:** High ratings (up to 5) for taste preference in Bangalore show strong consumer interest, but there are also lower ratings (1) in some instances, suggesting variability in consumer experiences.
#
# **Availability:**
#
# **Importance:** Availability is a recurring theme in cities like Bangalore and Hyderabad. Ensuring that the product is easily accessible is vital for maintaining customer satisfaction.
# **Current Status:** Ratings for availability vary widely, with some instances of low scores (1), indicating potential gaps in distribution.
# Recommendations
# Focus on Branding: Strengthening brand reputation should be a priority, especially in competitive markets like Mumbai and Pune. Consider marketing campaigns, partnerships, and community engagement to enhance brand image.
#
# Enhance Taste Experience: Given the importance of taste, invest in product development to refine flavors and cater to local preferences. Conduct taste tests and gather feedback to ensure product alignment with consumer expectations.
#
# **Improve Availability:**\
# Address gaps in availability by optimizing distribution channels. Ensuring that the product is readily available in key markets will support both brand reputation and customer satisfaction.
#
# **Conclusion**\
# A balanced approach focusing on branding and taste while also ensuring availability will likely yield the best results. Prioritizing branding and taste experience can create a strong foundation for customer loyalty and market growth.

# %% [markdown]
# # That is a rough work below:
# ### if you need for more analysis

# %%
df1.Consume_reason.value_counts()
# Out:
# Consume_reason
# Increased energy and focus       3574
# To combat fatigue                2428
# To enhance sports performance    1604
# To boost performance             1514
# Other                             880
# Name: count, dtype: int64

# %%
df1.Heard_before.value_counts()
# Out:
# Heard_before
# No     5553
# Yes    4447
# Name: count, dtype: int64

# %%
df1.Brand_perception.value_counts()
# Out:
# Brand_perception
# Neutral     5974
# Positive    2257
# Negative    1769
# Name: count, dtype: int64

# %%
df1.General_perception.value_counts()
# Out:
# General_perception
# Effective    2909
# Not sure     2610
# Healthy      2243
# Dangerous    2238
# Name: count, dtype: int64

# %%
df1.Reasons_preventing_trying.value_counts()
# Out:
# Reasons_preventing_trying
# Not available locally              2431
# Health concerns                    2258
# Not interested in energy drinks    2193
# Unfamiliar with the brand          1850
# Other                              1268
# Name: count, dtype: int64

# %%
df1.Improvements_desired.value_counts()
# Out:
# Improvements_desired
# Reduced sugar content       2995
# More natural ingredients    2498
# Wider range of flavors      2037
# Healthier alternatives      1472
# Other                        998
# Name: count, dtype: int64

# %%
df1.Health_concerns.value_counts()
# Out:
# Health_concerns
# Yes    6045
# No     3955
# Name: count, dtype: int64

# %%
df1.Interest_in_natural_or_organic.value_counts()
# Out:
# Interest_in_natural_or_organic
# Yes         4983
# No          3062
# Not Sure    1955
# Name: count, dtype: int64

# %%
df1.Limited_edition_packaging.value_counts()
# Out:
# Limited_edition_packaging
# No          4023
# Yes         3946
# Not Sure    2031
# Name: count, dtype: int64

# %%
df1.Price_range.value_counts()
# Out:
# Price_range
# 50-99        4288
# 100-150      3142
# Above 150    1561
# Below 50     1009
# Name: count, dtype: int64

# %%
df1.Typical_consumption_situations.value_counts()
# Out:
# Typical_consumption_situations
# Sports/exercise           4494
# Studying/working late     3231
# Social outings/parties    1487
# Other                      491
# Driving/commuting          297
# Name: count, dtype: int64

# %%
df2.nunique()
# Out:
# Respondent_ID    10000
# Name              9487
# Age                  5
# Gender               3
# City_ID             10
# dtype: int64

# %%
df2.describe()
# Out:
#        Respondent_ID
# count    10000.00000
# mean    125030.50000
# std       2886.89568
# min     120031.00000
# 25%     122530.75000
# 50%     125030.50000
# 75%     127530.25000
# max     130030.00000

# %%
df2.Age.value_counts()
# Out:
# Age
# 19-30    5520
# 31-45    2376
# 15-18    1488
# 46-65     426
# 65+       190
# Name: count, dtype: int64

# %%
df2.Gender.value_counts()
# Out:
# Gender
# Male          6038
# Female        3455
# Non-binary     507
# Name: count, dtype: int64

# %%
df2.City_ID.value_counts()
# Out:
# City_ID
# CT113    2828
# CT116    1833
# CT112    1510
# CT114     937
# CT118     906
# CT115     566
# CT117     456
# CT111     429
# CT119     360
# CT120     175
# Name: count, dtype: int64

# %%
df3.nunique()
# Out:
# City_ID    10
# City       10
# Tier        2
# dtype: int64

# %%
df3.describe()
# Out:
#        City_ID   City    Tier
# count       10     10      10
# unique      10     10       2
# top      CT111  Delhi  Tier 1
# freq         1      1       5

# %%
df3.Tier.value_counts()
# Out:
# Tier
# Tier 1    5
# Tier 2    5
# Name: count, dtype: int64
